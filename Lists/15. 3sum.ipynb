# %% [markdown]
# Given an integer array nums, return all the triplets [nums[i], nums[j], nums[k]] such that i != j, i != k, and j != k, and nums[i] + nums[j] + nums[k] == 0.
#
# Notice that the solution set must not contain duplicate triplets.

# %%
class Solution:
    def threeSum(self, nums: list[int]) -> list[list[int]]:
        target = 0
        nums.sort()
        output = []
        
        for i in range(len(nums)):
            if i > 0 and nums[i] == nums[i - 1]:
                continue
            
            j = i + 1
            k = len(nums) - 1
            
            while j < k:
                sum = nums[i] + nums[j] + nums[k]
                
                if sum == target:
                    output.append([nums[i], nums[j], nums[k]])
                    j += 1
                    k -= 1
                    
                    while j < k and nums[j] == nums[j - 1]:
                        j += 1
                    while j < k and nums[k] == nums[k + 1]:
                        k -= 1
                
                elif sum < target:
                    j += 1
                else:
                    k -= 1
                    
        return output

# %%
nums = [4,4,3,-5,0,0,0,-2,3,-5,-5,0]
output = Solution()
output.threeSum(nums)
# Out:
# [[0, 0, 0]]

# %%
'''
Couldn't solve in n^2. Real solution sorts and then uses a 2-pointer solution to skip over duplicate elements that are neighbors (for j and k)
, while incrementing i and reducing the search range.
'''
